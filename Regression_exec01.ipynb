# %% [markdown]
# <a href="https://colab.research.google.com/github/tonytsai5583/colab20230705/blob/main/Regression_exec01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.datasets import load_diabetes
diabetes = load_diabetes(scaled=False)
# DataFrame(2D) Series(1D)
data = pd.DataFrame(diabetes["data"], columns=diabetes["feature_names"])
data["ans"] = diabetes["target"]
data
# Out:
#       age  sex   bmi      bp     s1     s2    s3    s4      s5     s6    ans
# 0    59.0  2.0  32.1  101.00  157.0   93.2  38.0  4.00  4.8598   87.0  151.0
# 1    48.0  1.0  21.6   87.00  183.0  103.2  70.0  3.00  3.8918   69.0   75.0
# 2    72.0  2.0  30.5   93.00  156.0   93.6  41.0  4.00  4.6728   85.0  141.0
# 3    24.0  1.0  25.3   84.00  198.0  131.4  40.0  5.00  4.8903   89.0  206.0
# 4    50.0  1.0  23.0  101.00  192.0  125.4  52.0  4.00  4.2905   80.0  135.0
# ..    ...  ...   ...     ...    ...    ...   ...   ...     ...    ...    ...
# 437  60.0  2.0  28.2  112.00  185.0  113.8  42.0  4.00  4.9836   93.0  178.0
# 438  47.0  2.0  24.9   75.00  225.0  166.0  42.0  5.00  4.4427  102.0  104.0
# 439  60.0  2.0  24.9   99.67  162.0  106.6  43.0  3.77  4.1271   95.0  132.0
# 440  36.0  1.0  30.0   95.00  201.0  125.2  42.0  4.79  5.1299   85.0  220.0
# 441  36.0  1.0  19.6   71.00  250.0  133.2  97.0  3.00  4.5951   92.0   57.0
#
# [442 rows x 11 columns]

# %%
from sklearn.model_selection import train_test_split
x = data.drop("ans", axis=1)
y = data["ans"]
# [90% x, 10% x, 90% y, 10% y]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1)

# %%
from sklearn.tree import DecisionTreeRegressor
reg = DecisionTreeRegressor(max_depth=2)
reg.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=2)

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
plt.figure(figsize=[10, 10])
plot_tree(reg,
     feature_names=x.columns,
     filled=True)
# Out:
# [Text(0.5, 0.8333333333333334, 's5 <= -0.004\nsquared_error = 5947.696\nsamples = 397\nvalue = 151.657'),
#  Text(0.25, 0.5, 'bmi <= 0.006\nsquared_error = 3183.45\nsamples = 198\nvalue = 109.389'),
#  Text(0.125, 0.16666666666666666, 'squared_error = 2254.873\nsamples = 156\nvalue = 96.808'),
#  Text(0.375, 0.16666666666666666, 'squared_error = 3860.819\nsamples = 42\nvalue = 156.119'),
#  Text(0.75, 0.5, 'bmi <= 0.015\nsquared_error = 5151.682\nsamples = 199\nvalue = 193.714'),
#  Text(0.625, 0.16666666666666666, 'squared_error = 4101.601\nsamples = 104\nvalue = 163.933'),
#  Text(0.875, 0.16666666666666666, 'squared_error = 4267.416\nsamples = 95\nvalue = 226.316')]

# %%
reg.predict(x_train)
# Out:
# array([163.93269231, 156.11904762, 163.93269231, 226.31578947,
#        226.31578947, 226.31578947, 226.31578947, 163.93269231,
#        226.31578947,  96.80769231, 226.31578947, 163.93269231,
#        226.31578947,  96.80769231, 226.31578947, 163.93269231,
#         96.80769231, 156.11904762,  96.80769231,  96.80769231,
#         96.80769231,  96.80769231,  96.80769231, 163.93269231,
#        226.31578947, 226.31578947, 163.93269231, 156.11904762,
#        163.93269231, 156.11904762,  96.80769231,  96.80769231,
#        163.93269231, 156.11904762,  96.80769231,  96.80769231,
#        156.11904762, 163.93269231, 226.31578947,  96.80769231,
#        226.31578947, 226.31578947,  96.80769231,  96.80769231,
#        226.31578947, 156.11904762, 226.31578947, 226.31578947,
#        156.11904762,  96.80769231,  96.80769231, 163.93269231,
#        163.93269231, 156.11904762,  96.80769231,  96.80769231,
#         96.80769231, 226.31578947, 226.31578947, 226.31578947,
# ...
